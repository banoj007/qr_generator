# %%
# !pip install qrcode

"""
QR Code Generator Application
Author: Vamshidhar Reddy Jonnalagadda
Description: This program generates a QR code for a given URL input.
"""

import qrcode

def generate_qr_code(url):
    """
    Generates a QR code image for the provided URL
    and saves it as a PNG file.
    """

    # Create QR code object
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_H,
        box_size=10,
        border=4
    )

    # Add data to QR code
    qr.add_data(url)
    qr.make(fit=True)

    # Create image from QR code instance
    img = qr.make_image(fill_color="black", back_color="white")

    # Save the generated QR code
    img.save("generated_qr_code.png")

    print("QR Code successfully generated and saved as 'generated_qr_code.png'")

if __name__ == "__main__":
    # User input
    website_url = input("Enter the URL to generate QR Code: ")

    # Generate QR code
    generate_qr_code(website_url)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# ...
# Enter the URL to generate QR Code: https://www.bioxsystems.com
# QR Code successfully generated and saved as 'generated_qr_code.png'
